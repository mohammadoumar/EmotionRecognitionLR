# %% [markdown]
# # Data Pre-Processing

# %%
import os
import glob
import json
import random
import pandas as pd # type: ignore

# %%
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
data_dir = os.path.join(parent_dir, "data_files")

# %% [markdown]
# ### Read files into a dataframe

# %%
file_paths = glob.glob(os.path.join(data_dir, '*.xlsx'))

# %%
df_list = []

for file_path in file_paths:

    df = pd.read_excel(file_path)
    df['file_name'] = os.path.basename(file_path)
    df_list.append(df)

# %%
df = pd.concat(df_list, ignore_index=True)

# %% [markdown]
# ### Process dataframe

# %%
df = df[df['Annotations'].notna()].reset_index()

# %%
df[['raw_emotion', 'raw_speaker_id']] = df['Annotations'].str.split('\n\n', expand=True, n=1)

# %%
def process_emotion(x):

    raw_emotion = x.raw_emotion
    try:
        emotion = raw_emotion.split("\n")[1].split(":")[1]
    except:
        emotion = "no annotation"

    return emotion

# %%
df['emotion'] = df.apply(lambda x: process_emotion(x), axis=1)

# %%
def process_speaker(x):

    raw_speaker_id = x.raw_speaker_id
    
    try:
        if 'SpokenBy:' in raw_speaker_id.split("\n")[0]:
            speaker_id = raw_speaker_id.split("\n")[0].split(":")[1]
            
        elif 'SpokenBy:' in raw_speaker_id.split("\n")[1]:            
            speaker_id = raw_speaker_id.split("\n")[1].split(":")[1]
            
        elif 'SpokenBy:' in raw_speaker_id.split("\n")[2]:            
            speaker_id = raw_speaker_id.split("\n")[2].split(":")[1]

        return speaker_id
            
    except:
        
        speaker_id = "no annotation"

        return speaker_id

# %%
df['speaker_id'] = df.apply(lambda x: process_speaker(x), axis=1)

# %%
df = df.drop(columns=['index', 'Translated text in Spanish; Castilian', 'Number of words.1', 'Signs with spaces.1', 'Signs without spaces.1'])

# %%
df = df.rename(columns={'Source text in English': 'utterance', 'Annotations': 'raw_annotation'})

# %%
df = df.drop(columns=['Number of words', 'Signs with spaces', 'Signs without spaces'])

# %%
df = df.rename(columns={'Page': 'page_nr', 'Panel': 'panel_nr', 'Balloon': 'balloon_nr'})

# %%
df = df[['file_name', 'page_nr', 'panel_nr', 'balloon_nr', 'utterance', 'raw_annotation', 'raw_emotion', 'raw_speaker_id', 'emotion', 'speaker_id']]

# %% [markdown]
# ### train-test-split

# %%
titles_list = list(df.file_name.unique())
num_train = int(len(titles_list) * 0.7)

# %%
train_titles = random.sample(titles_list, num_train)
test_titles = [title for title in titles_list if title not in train_titles]

# %%
df['split'] = df['file_name'].apply(lambda x: 'TRAIN' if x in train_titles else ('TEST' if x in test_titles else 'UNKNOWN'))

# %% [markdown]
# #### clean dataframe

# %%
wrong_idx = [1093, 26, 1447]

# %%
df = df.drop(df.index[wrong_idx]).reset_index(drop=True)

# %%
speaker = df.iloc[1129]['raw_annotation'].split("\n\n")[0].split(":")[1]
emotion = df.iloc[1129]['raw_annotation'].split("\n\n")[1].split(":")[1]

# %%
df.iloc[1129, 8] = emotion
df.iloc[1129, 9] = speaker

# %%
speaker = df.iloc[1411]['raw_annotation'].split("\n\n")[0].split(":")[1]
emotion = df.iloc[1411]['raw_annotation'].split("\n\n")[1].split(":")[1]

# %%
df.iloc[1411, 8] = emotion
df.iloc[1411, 9] = speaker

# %%
df = df[df.emotion != "no annotation"].reset_index()

# %%
df.to_csv("comics_data_processed.csv")

# %% [markdown]
# ### dataframe grouped by titles

# %%
df_by_title = df.groupby('file_name').agg({'utterance': list, 'emotion': list, 'split': set}).reset_index()

# %%
def get_full_title_text(x):

    list_utterances = x.utterance
    full_title_text = ' '.join(list_utterances)

    return full_title_text

# %%
df_by_title['full_title_text'] = df_by_title.apply(lambda x: get_full_title_text(x), axis=1)

# %%
df_by_title = df_by_title.rename(columns={'utterance': 'utterances_l', 'emotion': 'emotions_l'})

# %%
def process_split(x):

    return list(x.split)[0]

# %%
df_by_title['split'] = df_by_title.apply(lambda x: process_split(x), axis=1)

# %%
def find_utterance_indices(row):

    title_text = row.full_title_text
    utterances_l = row.utterances_l

    start_indices = []
    end_indices = []
    
    for utterance in utterances_l:
        start = title_text.find(utterance)
        if start != -1:
            # Append the start index and calculate the end index
            start_indices.append(start)
            end_indices.append(start + len(utterance))
        else:
            # If substring not found, append -1 to both lists
            start_indices.append(-1)
            end_indices.append(-1)
    
    return start_indices, end_indices

# %%
df_by_title['start_indices', 'end_indices'] = df_by_title.apply(lambda row: find_utterance_indices(row), axis=1)

# %%
df_by_title[['start_indices', 'end_indices']] = pd.DataFrame(df_by_title[('start_indices', 'end_indices')].tolist(), index=df_by_title.index)

# %%
df_by_title.to_csv("comics_data_by_title.csv")

# %% [markdown]
# ### Prepare prompts

# %%
# Formatting Fx
# Build questoin
# Build answer

# %%
def formatting_fct(instruction="", input="", output=""):
    
    prompt_d ={
            
        "instruction": f"""{instruction}""",
        "input": f"""{input}""",
        "output": f"""{output}"""
            
        }
    
    return prompt_d

# %%
def build_instruction(nr_utterances):

    results = json.dumps(["emotion_class (str)"] * nr_utterances)

    instruction = f"""### You are an expert in Emotion Analysis. You are given the transcript of a comic book which contains numbered character utterances enclosed by <UT></UT> tags. Your task is to classify each utterance in the comic transcript as on the following emotion classes: "Anger" (AN), "Disgust" (DI), "Fear" (FE), "Sadness" (SA), "Surprise" (SU) or "Joy" (JO). You must return a list of emotion classes, strictly of length {nr_utterances}, in following JSON format: {{"list_emotion_classes": [["emotion_classes (str)"], ["emotion_classes (str)"] ... ["emotion_classes (str)"]]}} where each element "emotion_classes (str)" is replaced by one ore more of the following abbreviated emotion class labels: "AN", "DI", "FE", "SA", "SU" or "JO". 
"""    
    return instruction

# %%
# def build_tagged_text(text, start_indices, end_indices):

#     offset = 0

#     for i, (start_i, end_i) in enumerate(zip(start_indices, end_indices)):
            
#         start_tag = "<UT" + str(i+1) + ">"
#         end_tag = "</UT" + str(i+1) + ">"
        
#         start_idx = start_i + offset
#         end_idx = end_i + offset

#         offset = offset + (len(start_tag)  + len(end_tag))
        
#         text_r = text[start_idx:end_idx]
#         new_text = start_tag + text_r + end_tag
#         text = text.replace(text_r, new_text)

#         question = f"""### Here is the comic transcript: {text}"""

#     return question

# %%
def build_tagged_text(utterances_l):

    tagged_utterances_l = []

    for idx, utterance in enumerate(utterances_l):
        
        start_tag = "<UT" + str(idx+1) + ">"
        end_tag = "</UT" + str(idx+1) + ">"
        tagged_utterance = start_tag + utterance + end_tag
        tagged_utterances_l.append(tagged_utterance)
        
    tagged_title_text = ''.join(tagged_utterances_l)
    question = f"""### Here is the comic transcript: {tagged_title_text}"""

    return question

# %%
def build_answer(title_emotions):

    title_emotions_l = []
    emotion_class_labels = ["Anger", "Disgust", "Fear", "Sadness", "Surprise", "Joy"]

    for emotions_l in title_emotions:

            if emotions_l == 'Neutral':
                title_emotions_l.append([emotions_l])
            
            else:
                emotions_l = emotions_l.split("-")
               
                emotion_annotation_l = []

                for idx, emotion_annotation in enumerate(emotions_l):

                    if '0' not in emotion_annotation:
                 
                        #emotion_annotation_l.append(emotion_class_labels[idx])
                        emotion_annotation_l.append(emotion_annotation[:-1])
                    
                title_emotions_l.append(emotion_annotation_l)
                

    return json.dumps({"list_emotion_classes": title_emotions_l})

# %% [markdown]
# ### Build Data Files

# %%
df_train = df_by_title[df_by_title.split == 'TRAIN'].reset_index()

data_file_train = []

for index, _ in df_train.iterrows():
    
    i = index

    instruction = build_instruction(len(df_train.iloc[i].utterances_l))
    question = build_tagged_text(df_train.iloc[i].utterances_l)
    answer = build_answer(df_train.iloc[i].emotions_l)
    
    data_file_train.append( formatting_fct(instruction, question, answer) )

# %%
len(data_file_train)
# Out:
# 22

# %%
for i in range(3):
    print(data_file_train[i])
# Out:
# {'instruction': '### You are an expert in Emotion Analysis. You are given the transcript of a comic book which contains numbered character utterances enclosed by <UT></UT> tags. Your task is to classify each utterance in the comic transcript as on the following emotion classes: "Anger" (AN), "Disgust" (DI), "Fear" (FE), "Sadness" (SA), "Surprise" (SU) or "Joy" (JO). You must return a list of emotion classes, strictly of length 34, in following JSON format: {"list_emotion_classes": [["emotion_classes (str)"], ["emotion_classes (str)"] ... ["emotion_classes (str)"]]} where each element "emotion_classes (str)" is replaced by one ore more of the following abbreviated emotion class labels: "AN", "DI", "FE", "SA", "SU" or "JO". \n', 'input': '### Here is the comic transcript: <UT1>In Rio de Janeiro my brakes were cut.</UT1><UT2>In Mexico l was slipped psilocybin while fighting a pack of jaguars.</UT2><UT3>And now, in SHANGHAI…</UT3><UT4>< I\'VE GOT YOU! GO LIMP! > *</UT4><UT5>< THIS DOESN\'T --MY POLYETHYLENE LINES ARE IMPOSSIBLE TO BREAK! ></UT5><UT6>< BUT NOT IMPOSSIBLE… ></UT6><UT7><… TO CUT. ></UT7><UT8>It\'s HIM.</UT8><UT9>< I KNOW THE POLICE ARE AFTER ME FOR MY " SKYSPIDER " STUNTS. BUT WHY YOU? ></UT9><UT10>Jealousy? Some sick game?</UT10><UT11>If he\'s HERE, he must have…</UT11><UT12>Dammit. I should have figured it out based on SKYSPIDER\'S mask…</UT12><UT13>< QIU. HAVE YOU TRAINED ANYONE ELSE LATELY? ></UT13><UT14>< I… YEAH. ></UT14><UT15>< A GUY AROUND YOUR AGE. COULDN\'T PLACE HIS ACCENT. ></UT15><UT16>< CALLED HIMSELF "ANTON." ></UT16><UT17>He didn\'t even bother to use a DIFFERENT fake name…</UT17><UT18>… because he wants me to know he\'s one step ahead of me.</UT18><UT19>Like in DUBLIN.</UT19><UT20>Or METROPOLIS.</UT20><UT21>Or MOROCCO.</UT21><UT22>Where he ended the life of our master Ouahbi once he realized he was training a PSYCHOPATH.</UT22><UT23>I miss my friend.</UT23><UT24>I miss who I thought he was.</UT24><UT25>He haunts me now, like a ghost, as I near the finish line.</UT25><UT26>My mission has always been about saving people, but Anton…</UT26><UT27>… I\'m afraid one day he might kill me. He has all my skills, but his mind has no distractions, whereas mine…</UT27><UT28>I have FEAR.</UT28><UT29>I\'m afraid I won\'t be able to save myself and this mission will end and I\'ll join my parents in the ground.</UT29><UT30>So I need to visit one more MASTER…</UT30><UT31>… to make my MIND ready.</UT31><UT32>To make me COLD AND TERRIFYING.</UT32><UT33>To make me a creature of the NIGHT.</UT33><UT34>PLEASE, COME IN, MR. WAYNE…</UT34>', 'output': '{"list_emotion_classes": [["AN", "FE", "SU"], ["AN", "FE", "SA"], ["AN", "FE", "SA"], ["FE", "SA", "SU"], ["AN", "JO"], ["JO"], ["JO"], ["SU"], ["AN", "SU"], ["AN", "SU"], ["FE", "SU"], ["AN", "DI", "SA", "SU"], ["FE", "SA"], ["FE", "SU", "JO"], ["Neutral"], ["Neutral"], ["AN", "DI", "SU"], ["AN", "DI"], ["AN", "DI"], ["AN", "DI"], ["AN", "DI"], ["AN", "DI", "SA"], ["SA"], ["SA"], ["FE", "SA"], ["AN", "DI", "SA"], ["FE", "SA"], ["FE"], ["FE", "SA"], ["Neutral"], ["Neutral"], ["Neutral"], ["JO"], ["JO"]]}'}
# {'instruction': '### You are an expert in Emotion Analysis. You are given the transcript of a comic book which contains numbered character utterances enclosed by <UT></UT> tags. Your task is to classify each utterance in the comic transcript as on the following emotion classes: "Anger" (AN), "Disgust" (DI), "Fear" (FE), "Sadness" (SA), "Surprise" (SU) or "Joy" (JO). You must return a list of emotion classes, strictly of length 139, in following JSON format: {"list_emotion_classes": [["emotion_classes (str)"], ["emotion_classes (str)"] ... ["emotion_classes (str)"]]} where each element "emotion_classes (str)" is replaced by one ore more of the following abbreviated emotion class labels: "AN", "DI", "FE", "SA", "SU" or "JO". \n', 'input': '### Here is the comic transcript: <UT1>DID YOU HAVE TO ELECTROCUTE HER SO HARD?</UT1><UT2>IT\'S NOT LIKE I HAVE DIFFERENT SETTINGS.</UT2><UT3>YOU\'RE ELECTROCUTIONER. IT\'S YOUR WHOLE THING. YOU\'D THINK YOU\'D HAVE SOME DEGREE OF CONTROL?</UT3><UT4>OH, HEY. I THINK SHE\'S AWAKE.</UT4><UT5>WELCOME BACK, MADAM MAYOR. BLOCKBUSTER IS PRETTY PISSED WITH YOU.</UT5><UT6>HE KNOWS YOU\'RE WORKING WITH DICK GRAYSON.</UT6><UT7>HE WANTS ME TO GET INFORMATION OUT OF YOU.</UT7><UT8>SHE\'S AWAKE, BOSS. SHE--</UT8><UT9>CAN YOU WALK?</UT9><UT10>HOW DID YOU FIND ME?</UT10><UT11>ORACLE HAD THE LAST PING OFF YOUR PHONE. AND AUDRE FOLLOWED BLOCKBUSTER\'S LIMO.</UT11><UT12>AUDRE\'S HERE?</UT12><UT13>IN A CAR OUTSIDE.</UT13><UT14>SHE WASN\'T SUPPOSED TO FOLLOW. I TOLD HER I\'D BE OKAY.</UT14><UT15>SURE. AND I CAN APPRECIATE THAT AS THE POSTER BOY FOR STUBBORN SELF-RELIANCE.</UT15><UT16>BUT I THINK YOU HAVE TO CEDE THE MORAL HIGH GROUND TO AUDRE HERE, SEEING AS YOU WERE KIDNAPPED AND ELECTROCUTED.</UT16><UT17>NIGHTWING…</UT17><UT18>I AM VERY DISAPPOINTED TO SEE THIS, MELINDA.</UT18><UT19>OKAY…</UT19><UT20>… I GUESS WE\'RE GOING THROUGH YOU.</UT20><UT21>YOU THINK YOU CAN GO THROUGH ME?! NOTHING CAN--</UT21><UT22>GET IN!</UT22><UT23>AUDRE!</UT23><UT24>HEY!</UT24><UT25>#HNNNN. </UT25><UT26>GO. GO. GO.</UT26><UT27>" TELL US EVERYTHING YOU KNOW. "</UT27><UT28>YOU WORKING FOR MAGGIE SAWYER NOW, ARE YOU, DETECTIVES?</UT28><UT29>I\'VE NEVER BEEN YOUR BIGGEST FAN, EX-COMMISSIONER MACLEAN. I\'M MORE THAN HAPPY TO PUT YOU AWAY.</UT29><UT30>OH, I\'M NOT GOING AWAY.</UT30><UT31>THERE\'S A FILE.</UT31><UT32>WHAT FILE?</UT32><UT33>A BLOCKBUSTER FILE. EVERY INTEREST HE HAS. SPREADSHEETS. DROP-OFFS. ACCOUNTS. HE ASKED ME TO KEEP IT SAFE.</UT33><UT34>WHERE IS IT?</UT34><UT35>I… CAN\'T ANSWER THAT.</UT35><UT36>DO YOU NOT HAVE IT, THEN?</UT36><UT37>OF COURSE I HAVE IT. BUT IT\'S HIDDEN.</UT37><UT38>DOES ANYONE OTHER THAN YOU KNOW WHERE IT\'S HIDDEN?</UT38><UT39>ABSOLUTELY NOT. IT\'S MY INSURANCE. THE ONLY WAY ANYONE GETS THEIR HANDS ON THOSE FILES IS IF I GET FULL IMMUNITY.</UT39><UT40>SO, YOU\'LL TURN THE FILES OVER IF YOU\'RE PROMISED PROTECTION?</UT40><UT41>MAGGIE SAWYER WOULD HAVE TO ASK VERY NICELY BUT, YES, I THINK WE COULD MAKE A DEAL.</UT41><UT42>THAT\'S A SHAME.</UT42><UT43>WHAT DO YOU MEAN?</UT43><UT44>THAT\'S NOT WHAT BLOCKBUSTER WANTED TO HEAR AT ALL.</UT44><UT45>@ # $ %.</UT45><UT46>WHO WAS IN HERE WITH HIM?</UT46><UT47>WHO?!</UT47><UT48>THIS @ # $ % # & CITY!</UT48><UT49>MAGGIE.</UT49><UT50>IT\'S THE MAYOR. SHE WANTS TO TALK. IN PRIVATE.</UT50><UT51>COMMISSIONER. I HAVE BEEN WORKING TO BRING DOWN BLOCKBUSTER AND MARONI… IN SECRET.</UT51><UT52>SUPPOSING I CHOOSE TO BELIEVE YOU, IF IT\'S A SECRET, WHY ARE YOU TELLING ME?</UT52><UT53>BECAUSE BLOCKBUSTER KNOWS I\'M WORKING AGAINST HIM NOW. BUT HE DOESN\'T KNOW WHAT I HAVE ON HIM.</UT53><UT54>I HAVE ENOUGH TO TAKE DOWN SEVERAL OF HIS MAJOR OPERATIONS. BUT WE ONLY GET ONE CHANCE AT THIS. WE HAVE TO ACT TONIGHT.</UT54><UT55>AND HOW WOULD YOU PROPOSE WE DO THAT?</UT55><UT56>FOLLOW ME. PLEASE.</UT56><UT57>WE JUST NEED TO CATCH THEM IN THE ACT…</UT57><UT58>… WE KNOW WHERE THEY\'RE GOING TO BE. WE KNOW WHAT THEY\'RE GOING TO DO.</UT58><UT59>EVEN IF THAT\'S TRUE, I DON\'T HAVE ENOUGH ...
# {'instruction': '### You are an expert in Emotion Analysis. You are given the transcript of a comic book which contains numbered character utterances enclosed by <UT></UT> tags. Your task is to classify each utterance in the comic transcript as on the following emotion classes: "Anger" (AN), "Disgust" (DI), "Fear" (FE), "Sadness" (SA), "Surprise" (SU) or "Joy" (JO). You must return a list of emotion classes, strictly of length 183, in following JSON format: {"list_emotion_classes": [["emotion_classes (str)"], ["emotion_classes (str)"] ... ["emotion_classes (str)"]]} where each element "emotion_classes (str)" is replaced by one ore more of the following abbreviated emotion class labels: "AN", "DI", "FE", "SA", "SU" or "JO". \n', 'input': '### Here is the comic transcript: <UT1>" Tell me another story, Momma. "</UT1><UT2>" What kind of story, Eleanor? "</UT2><UT3>" One about John.</UT3><UT4>" Tell me how he became the Guardian. "</UT4><UT5>" Well, your brother doesn\'t like to talk about it much. You know that.</UT5><UT6>" Nuh-uh. "</UT6><UT7>" A marine is a kind of soldier.</UT7><UT8>" Before long, John and a lot of other soldiers got sent across the ocean to fight a war. "</UT8><UT9>No!</UT9><UT10>Kyle!</UT10><UT11>" And while he was there… just like every war that ever was…</UT11><UT12>"… something terrible happened. "</UT12><UT13>#YAAARRRRRGGH!</UT13><UT14>" Bad enough that John did something he wasn\'t in the habit of doing back then. "</UT14><UT15>KYLE!</UT15><UT16>Jason, it\'s too late!</UT16><UT17>" He prayed. "</UT17><UT18>John.</UT18><UT19>John, We need you.</UT19><UT20>" He prayed for the strength to save the people who needed him.</UT20><UT21>" And in a flash of light, where your brother stood… "</UT21><UT22>… there stood an invincible knight, his eyes blazing with the light of heaven.</UT22><UT23>That\'s how your brother became a superhero, sweetie. Earth\'s first and greatest.</UT23><UT24>After the Battle of Oa, he founded a team of Lanterns called the Watchtower to protect Earth while he flew all over the Multiverse.</UT24><UT25>Isn\'t that nice?</UT25><UT26>#Uh-huh.</UT26><UT27>Enough, all right? I\'m working on it. Can I stop hearing about it, please?</UT27><UT28>You\'re only hearing about it because you\'re sneaking around back there instead of working.</UT28><UT29>Nobody\'s sneaking! Can\'t I take a minute to look at my girls?</UT29><UT30>One day, when he\'d done what he set out to do, he took off his ring, and passed it on.</UT30><UT31>He became an architect, like he\'d always wanted.</UT31><UT32>And now we all live here together in the house he built for us, and he\'s finally putting up a fence to keep the rabbits out of my flowers.</UT32><UT33>Just pretend I\'m not here, all right?</UT33><UT34>#Hmm.</UT34><UT35>What about the war, Momma? What if the…</UT35><UT36>… th-the…</UT36><UT37>JOHN.</UT37><UT38>JOHN.</UT38><UT39>WE NEED YOU.</UT39><UT40>Rayner? Is that you?</UT40><UT41>THEY\'VE FOUND HER, JOHN.</UT41><UT42>MANY OF US HAVE FALLEN.</UT42><UT43>THE BRIGHT REVENANT IS WITH THEM.</UT43><UT44>What, Momma?</UT44><UT45>Did something happen again?</UT45><UT46>I-it\'s nothing, sweetie. Why don\'t you practice your reading for a bit?</UT46><UT47>I need to talk to your brother.</UT47><UT48>You told me you formed the Watchtower so they wouldn\'t need you anymore. That you were done fighting.</UT48><UT49>It\'s nothing to worry about. The Corps just needs a hand with--</UT49><UT50>Don\'t talk to me like I\'m stupid, John. She said, " They found her. "</UT50><UT51>You gave me back the daughter I buried. The same age she was when I lost her, and she hasn\'t aged a day since then. </UT51><UT52>I know a miracle like that has to be paid back someday.</UT52><UT53>Tell me the truth, John…</UT53><UT54>… is that day today?</UT54><UT55>They\'re called the Radiant Dead.</UT55><UT56>They\'re the ones that killed the Old Guardians.</UT56><UT57>If they\'d killed the Central Battery like they meant to, there wouldn\'t be a Corps  ...

# %%
df_test = df_by_title[df_by_title.split == 'TEST'].reset_index()

data_file_test = []

for index, _ in df_test.iterrows():
    
    i = index

    instruction = build_instruction(len(df_test.iloc[i].utterances_l))
    question = build_tagged_text(df_test.iloc[i].utterances_l)
    answer = build_answer(df_test.iloc[i].emotions_l)
    
    data_file_test.append( formatting_fct(instruction, question, answer) )

# %% [markdown]
# ### Create and save JSON files

# %%
file_path = os.path.join(os.getcwd(), "../datasets/comics_train.json")

with open(file_path, 'w') as file:
    
    json.dump(data_file_train, file)

# %%
file_path = os.path.join(os.getcwd(), "../datasets/comics_test.json")

with open(file_path, 'w') as file:
    
    json.dump(data_file_test, file)

# %% [markdown]
# ### Data Process by a Single Title

# %%
df
# Out:
#       index                                          file_name  page_nr  \
# 0         0  QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1
# 1         1  QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1
# 2         2  QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1
# 3         3  QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1
# 4         4  QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...        1
# ...     ...                                                ...      ...
# 5277   5290  QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...       20
# 5278   5291  QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...       20
# 5279   5292  QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...       20
# 5280   5293  QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...       20
# 5281   5294  QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...       20
#
#       panel_nr  balloon_nr                                          utterance  \
# 0            2           1           DID YOU HAVE TO ELECTROCUTE HER SO HARD?
# 1            2           2           IT'S NOT LIKE I HAVE DIFFERENT SETTINGS.
# 2            2           3  YOU'RE ELECTROCUTIONER. IT'S YOUR WHOLE THING....
# 3            3           1                      OH, HEY. I THINK SHE'S AWAKE.
# 4            4           1  WELCOME BACK, MADAM MAYOR. BLOCKBUSTER IS PRET...
# ...        ...         ...                                                ...
# 5277         1           1  I KNOW THE BEINGS OF THIS WORLD ARE TRYING TO ...
# 5278         1           2               … BUT I WILL CRUSH THEM IN DUE TIME!
# 5279         2           1                               FOR MY FIRST TASK...
# 5280         2           2          … I MUST REMOVE THIS WORLD OF THEIR GODS!
# 5281         2           3         TRIMYSCIRA! DARKYLOSEID IS COMING FOR YOU!
#
#                                          raw_annotation  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN3-DI0-F...
# ...                                                 ...
# 5277  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5278  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5279  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5280  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5281  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
#
#                                             raw_emotion  \
# 0     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 1     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 2     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 3     2024-08-27 - aselermekova20\nFeeling:AN0-DI0-F...
# 4     2024-08-27 - aselermekova20\nFeeling:AN3-DI0-F...
# ...                                                 ...
# 5277  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5278  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5279  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5280  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
# 5281  2024-08-27 - aselermekova20\nFeeling:AN5-DI0-F...
#
#                                          raw_speaker_id  \
# 0           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# 1           2024-09-05 - aidaraliev12345\nSpokenBy:ID-2
# 2           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# 3           2024-09-05 - aidaraliev12345\nSpokenBy:ID-2
# 4           2024-09-05 - aidaraliev12345\nSpokenBy:ID-1
# ...                                                 ...
# 5277  2024-09-05 - aidaraliev12345\nSpokenBy:BLACKMA...
# 5278  2024-09-05 - aidaraliev12345\nSpokenBy:BLACKMA...
# 5279  2024-09-05 - aidaraliev12345\nSpokenBy:BLACKMA...
# 5280  2024-09-05 - aidaraliev12345\nSpokenBy:BLACKMA...
# 5281  2024-08-27 - aselermekova20\nSpokenBy:BLACKMAN...
#
#                       emotion        speaker_id  split
# 0     AN0-DI0-FE3-SA0-SU5-JO0              ID-1  TRAIN
# 1     AN0-DI0-FE0-SA0-SU5-JO0              ID-2  TRAIN
# 2     AN0-DI0-FE2-SA0-SU0-JO0              ID-1  TRAIN
# 3     AN0-DI0-FE0-SA0-SU4-JO0              ID-2  TRAIN
# 4     AN3-DI0-FE0-SA0-SU0-JO0              ID-1  TRAIN
# ...                       ...               ...    ...
# 5277  AN5-DI0-FE0-SA0-SU0-JO0  BLACKMANTASAURUS   TEST
# 5278  AN5-DI0-FE0-SA0-SU0-JO0  BLACKMANTASAURUS   TEST
# 5279  AN5-DI0-FE0-SA0-SU0-JO0  BLACKMANTASAURUS   TEST
# 5280  AN5-DI0-FE0-SA0-SU0-JO5  BLACKMANTASAURUS   TEST
# 5281  AN5-DI0-FE0-SA0-SU0-JO0  BLACKMANTASAURUS   TEST
#
# [5282 rows x 12 columns]

# %%
df_by_title
# Out:
#                                             file_name  \
# 0      QC copy - 1492 - 03 Batman El Caballero 8.xlsx
# 1   QC copy - 1499 - 58 ECC Co_mics 50 _The Jurass...
# 2   QC copy - 1500 - 04 Nightwing 19 _Nightwing 95...
# 3   QC copy - 1501 - 09 Mundos sin Liga de la Just...
# 4   QC copy - 1502 - 09 Mundos sin Liga de la Just...
# 5   QC copy - 1503 - 10 Crisis Oscura Flash - FLS ...
# 6            QC copy - 1507 - 22 Calle Peligro 1.xlsx
# 7       QC copy - 1508 - 48 Pequen_os Titanes 25.xlsx
# 8            QC copy - 1513 - 21 Blanco Humano 9.xlsx
# 9   QC copy - 1514 - 15 DC contra Vampiros 11 (1)....
# 10  QC copy - 1518 - 50 Las asombrosas aventuras d...
# 11     QC copy - 1520 - 51 Sonic The Hedgehog 44.xlsx
# 12             QC copy - 1521 - 40 Amor eterno 2.xlsx
# 13  QC copy - 1559 - 36 Fantasmas vol. 1 - Ghosted...
# 14  QC copy - 1560 - 36 Fantasmas vol. 1 - Ghosted...
# 15  QC copy - 1561 - 36 Fantasmas vol. 1 - Ghosted...
# 16  QC copy - 1562 - 36 Fantasmas vol. 1 - Ghosted...
# 17  QC copy - 1563 - 36 Fantasmas vol. 1 - Ghosted...
# 18  QC copy - 1567 - 36 Fantasmas vol. 1 - Ghosted...
# 19  QC copy - 1568 - 36 Fantasmas vol. 1 - Ghosted...
# 20  QC copy - 1569 - 36 Fantasmas vol. 1 - Ghosted...
# 21  QC copy - 1570 - 36 Fantasmas vol. 1 - Ghosted...
# 22  QC copy - 1571 - 36 Fantasmas vol. 1 - Ghosted...
# 23  QC copy - 1642 - 23 American Vampire vol. 4 - ...
# 24  QC copy - 1643 - 23 American Vampire vol. 4 - ...
# 25  QC copy - 1644 - 23 American Vampire vol. 4 - ...
# 26  QC copy - 1660 - 39 Dragon Age vol. 3 Engano -...
# 27  QC copy - 1661 - 39 Dragon Age vol. 3 Engano -...
# 28  QC copy - 1662 - 39 Dragon Age vol. 3 Engano -...
# 29  QC copy - 1733 - 34 The Walking Dead vol 15 - ...
# 30  QC copy - 1910 - 35 Ladro_n de ladrones 1 - To...
# 31                QC copy - 2200 - Stillwater 13.xlsx
#
#                                          utterances_l  \
# 0   [In Rio de Janeiro my brakes were cut., In Mex...
# 1   [THIS VILE THING ATTACKED THE SMALL BEASTS OF ...
# 2   [DID YOU HAVE TO ELECTROCUTE HER SO HARD?, IT'...
# 3   [" Tell me another story, Momma. ", " What kin...
# 4   [MOTHERFRAGGER., " AND WHEN HE SAW THE BLASPHE...
# 5   [I'M DONE LETTING YOU TORTURE ME!, YOU'RE NEVE...
# 6   [HOW'S IT GOING?, HEY., CAN I GET YOU ANYTHING...
# 7   [ SO, LET ME GET THIS STRAIGHT… THERE'S A SUPE...
# 8   [I'M ALREADY TOO LATE., $ % # @., I'M ALSO TOO...
# 9   [STILL WARM., WHOEVER WAS HERE, THEY LEFT QUIC...
# 10  [YOU AREN'T READY FOR THIS KIND OF PAIN, DONNI...
# 11  [YOU'RE NOT GOING TO OVER POWER TAILS' TECH., ...
# 12  [I WAS THE DAUGHTER OF THE NURSEMAID. HE WAS T...
# 13  [Aldus Trask was never really a doctor, not in...
# 14  [#UK, UK,, #UK., Ya see this?, This is why you...
# 15  [" SO THE PLAN HAS ALWAYS BEEN THAT WE NEED TO...
# 16  [Something I'm often accused of is using peopl...
# 17  [YOU'RE NEXT, SUPERSTAR!, You get used to it. ...
# 18  [YOU'VE BEEN NAUGHTY, JACKSON WINTERS., A CURI...
# 19  [HOLA, AMIGO. I GOT WHAT YOU NEED., NAH, MAN. ...
# 20  [IF YOUR PLAN IS TO TORTURE ME, DON'T BOTHER. ...
# 21  [I've always had a way with the ladies., Or at...
# 22  [TRICK!, TRICK? DAMMIT!, WHERE ARE YOU, YA OLD...
# 23  [@ANY SIGN OF THEM?, NEGATIVE, SIR. ADAM AND E...
# 24  [TIME TO FACE OUR FEARS, PEOPLE…, IT'S TIME TO...
# 25  [WHAT THE HELL… SKINNER…?!, IT'S TOO LATE, POO...
# 26  [THEY SAY THERE ARE NO SMALL ROLES. ONLY SMALL...
# 27  [EXCUSE ME. I'M LOOKING FOR A WOMAN., HER NAME...
# 28  [I MEANT NO OFFENSE!, IT'S COMMON KNOWLEDGE TH...
# 29  [THERE WERE THESE TWO BOYS, BEN AND BILLY. THE...
# 30  [THAT WENT… A LOT SMOOTHER THAN I EXPECTED.  ,...
# 31  [WE HAVE A SITUATION AT THE EDGE, AT --AT THE ...
#
#                                            emotions_l  split  \
# 0   [AN3-DI0-FE3-SA0-SU3-JO0, AN3-DI0-FE3-SA2-SU0-...  TRAIN
# 1   [AN5-DI0-FE0-SA0-SU0-JO0, AN5-DI0-FE0-SA0-SU0-...   TEST
# 2   [AN0-DI0-FE3-SA0-SU5-JO0, AN0-DI0-FE0-SA0-SU5-...  TRAIN
# 3   [AN0-DI0-FE0-SA0-SU0-JO3, AN0-DI0-FE0-SA0-SU3-...  TRAIN
# 4   [AN5-DI0-FE0-SA0-SU0-JO0, AN3-DI0-FE0-SA0-SU5-...  TRAIN
# 5   [AN5-DI0-FE0-SA0-SU0-JO0, AN5-DI0-FE0-SA2-SU0-...  TRAIN
# 6   [AN0-DI0-FE0-SA0-SU2-JO3, AN0-DI0-FE0-SA0-SU0-...   TEST
# 7   [AN0-DI0-FE0-SA0-SU3-JO0, AN0-DI0-FE0-SA0-SU5-...   TEST
# 8   [AN0-DI0-FE3-SA3-SU0-JO0, AN5-DI0-FE0-SA0-SU0-...  TRAIN
# 9   [AN0-DI0-FE2-SA0-SU3-JO0, AN0-DI0-FE3-SA0-SU3-...  TRAIN
# 10  [AN4-DI0-FE0-SA0-SU0-JO0, AN3-DI0-FE0-SA0-SU0-...  TRAIN
# 11  [AN0-DI0-FE0-SA0-SU0-JO1, AN0-DI0-FE0-SA0-SU0-...   TEST
# 12  [AN0-DI0-FE0-SA1-SU0-JO0, AN0-DI0-FE3-SA3-SU0-...   TEST
# 13  [Neutral, Neutral, Neutral, Neutral, AN0-DI0-F...   TEST
# 14  [AN3-DI0-FE2-SA0-SU0-JO0, AN3-DI0-FE2-SA0-SU0-...   TEST
# 15  [AN0-DI0-FE0-SA0-SU2-JO0, AN0-DI0-FE0-SA1-SU0-...   TEST
# 16  [AN0-DI0-FE0-SA3-SU0-JO0, AN0-DI0-FE0-SA3-SU0-...  TRAIN
# 17  [AN1-DI0-FE0-SA0-SU0-JO4, AN1-DI3-FE0-SA1-SU0-...  TRAIN
# 18  [AN2-DI1-FE0-SA0-SU0-JO0, AN2-DI0-FE0-SA2-SU0-...  TRAIN
# 19  [AN0-DI0-FE0-SA0-SU0-JO3, AN1-DI1-FE0-SA0-SU0-...  TRAIN
# 20  [AN0-DI0-FE0-SA3-SU0-JO0, AN0-DI0-FE0-SA3-SU0-...  TRAIN
# 21  [AN0-DI0-FE0-SA0-SU0-JO2, AN0-DI0-FE0-SA3-SU0-...   TEST
# 22  [AN0-DI0-FE3-SA0-SU0-JO0, AN2-DI0-FE4-SA0-SU2-...  TRAIN
# 23  [AN0-DI0-FE0-SA0-SU3-JO0, AN0-DI0-FE2-SA0-SU0-...  TRAIN
# 24  [Neutral, AN0-DI0-FE0-SA0-SU0-JO3, AN0-DI0-FE0...  TRAIN
# 25  [AN4-DI0-FE4-SA0-SU5-JO0, AN0-DI0-FE4-SA0-SU0-...  TRAIN
# 26  [AN2-DI2-FE0-SA0-SU0-JO0, AN4-DI2-FE0-SA0-SU0-...  TRAIN
# 27  [AN0-DI0-FE2-SA2-SU0-JO0, AN0-DI0-FE2-SA2-SU0-...  TRAIN
# 28  [AN0-DI0-FE0-SA5-SU3-JO0, AN0-DI0-FE0-SA4-SU0-...  TRAIN
# 29  [AN0-DI0-FE0-SA4-SU0-JO0, AN0-DI0-FE0-SA4-SU0-...  TRAIN
# 30  [AN0-DI0-FE0-SA0-SU0-JO1, AN1-DI0-FE0-SA1-SU0-...  TRAIN
# 31  [AN0-DI0-FE3-SA0-SU3-JO0, AN0-DI0-FE3-SA0-SU0-...   TEST
#
#                                       full_title_text  \
# 0   In Rio de Janeiro my brakes were cut. In Mexic...
# 1   THIS VILE THING ATTACKED THE SMALL BEASTS OF M...
# 2   DID YOU HAVE TO ELECTROCUTE HER SO HARD? IT'S ...
# 3   " Tell me another story, Momma. " " What kind ...
# 4   MOTHERFRAGGER. " AND WHEN HE SAW THE BLASPHEMI...
# 5   I'M DONE LETTING YOU TORTURE ME! YOU'RE NEVER ...
# 6   HOW'S IT GOING? HEY. CAN I GET YOU ANYTHING? J...
# 7    SO, LET ME GET THIS STRAIGHT… THERE'S A SUPER...
# 8   I'M ALREADY TOO LATE. $ % # @. I'M ALSO TOO EA...
# 9   STILL WARM. WHOEVER WAS HERE, THEY LEFT QUICKL...
# 10  YOU AREN'T READY FOR THIS KIND OF PAIN, DONNIE...
# 11  YOU'RE NOT GOING TO OVER POWER TAILS' TECH. ON...
# 12  I WAS THE DAUGHTER OF THE NURSEMAID. HE WAS TH...
# 13  Aldus Trask was never really a doctor, not in ...
# 14  #UK, UK, #UK. Ya see this? This is why you alw...
# 15  " SO THE PLAN HAS ALWAYS BEEN THAT WE NEED TO ...
# 16  Something I'm often accused of is using people...
# 17  YOU'RE NEXT, SUPERSTAR! You get used to it.   ...
# 18  YOU'VE BEEN NAUGHTY, JACKSON WINTERS. A CURIOU...
# 19  HOLA, AMIGO. I GOT WHAT YOU NEED. NAH, MAN. NO...
# 20  IF YOUR PLAN IS TO TORTURE ME, DON'T BOTHER. J...
# 21  I've always had a way with the ladies. Or at l...
# 22  TRICK! TRICK? DAMMIT! WHERE ARE YOU, YA OLD BA...
# 23  @ANY SIGN OF THEM? NEGATIVE, SIR. ADAM AND EVE...
# 24  TIME TO FACE OUR FEARS, PEOPLE… IT'S TIME TO L...
# 25  WHAT THE HELL… SKINNER…?! IT'S TOO LATE, POOLE...
# 26  THEY SAY THERE ARE NO SMALL ROLES. ONLY SMALL ...
# 27  EXCUSE ME. I'M LOOKING FOR A WOMAN. HER NAME'S...
# 28  I MEANT NO OFFENSE! IT'S COMMON KNOWLEDGE THAT...
# 29  THERE WERE THESE TWO BOYS, BEN AND BILLY. THEI...
# 30  THAT WENT… A LOT SMOOTHER THAN I EXPECTED.   U...
# 31  WE HAVE A SITUATION AT THE EDGE, AT --AT THE P...
#
#                          (start_indices, end_indices)  \
# 0   ([0, 38, 107, 129, 158, 224, 248, 261, 271, 34...
# 1   ([0, 57, 118, 129, 137, 203, 214, 237, 244, 25...
# 2   ([0, 41, 82, 176, 206, 272, 315, 358, 383, 397...
# 3   ([0, 34, 67, 85, 125, 197, 209, 242, 334, 338,...
# 4   ([0, 15, 93, 117, 227, 321, 326, 446, 563, 575...
# 5   ([0, 33, 77, 141, 374, 394, 591, 622, 741, 800...
# 6   ([0, 16, 21, 45, 58, 75, 83, 117, 133, 150, 16...
# 7   ([0, 110, 135, 154, 170, 186, 186, 208, 220, 2...
# 8   ([0, 22, 31, 70, 96, 102, 115, 184, 208, 214, ...
# 9   ([0, 12, 49, 118, 146, 269, 309, 319, 371, 398...
# 10  ([0, 48, 61, 111, 156, 212, 226, 246, 251, 326...
# 11  ([0, 44, 58, 80, 92, 99, 128, 152, 161, 297, 3...
# 12  ([0, 159, 272, 310, 428, 495, 628, 767, 872, 9...
# 13  ([0, 67, 137, 289, 323, 395, 461, 519, 542, 55...
# 14  ([0, 9, 14, 27, 63, 203, 252, 301, 328, 384, 5...
# 15  ([0, 88, 198, 274, 284, 377, 461, 505, 535, 58...
# 16  ([0, 82, 165, 177, 188, 201, 224, 244, 255, 30...
# 17  ([0, 24, 46, 100, 125, 162, 194, 292, 346, 442...
# 18  ([0, 38, 99, 175, 288, 423, 483, 502, 569, 619...
# 19  ([0, 34, 58, 138, 181, 187, 249, 291, 321, 344...
# 20  ([0, 72, 89, 106, 122, 135, 190, 213, 276, 285...
# 21  ([0, 39, 63, 111, 130, 249, 335, 446, 496, 525...
# 22  ([0, 7, 22, 54, 106, 185, 218, 248, 274, 283, ...
# 23  ([0, 19, 77, 95, 129, 188, 258, 267, 385, 397,...
# 24  ([0, 32, 52, 96, 106, 115, 130, 162, 176, 197,...
# 25  ([0, 26, 78, 141, 149, 264, 275, 311, 319, 368...
# 26  ([0, 54, 122, 150, 176, 196, 279, 371, 430, 45...
# 27  ([0, 36, 131, 159, 196, 237, 271, 311, 333, 35...
# 28  ([0, 20, 113, 213, 256, 286, 320, 421, 475, 51...
# 29  ([0, 89, 111, 234, 318, 336, 370, 399, 550, 68...
# 30  ([0, 45, 106, 129, 176, 185, 195, 272, 328, 36...
# 31  ([0, 51, 71, 103, 123, 146, 185, 207, 229, 234...
#
#                                         start_indices  \
# 0   [0, 38, 107, 129, 158, 224, 248, 261, 271, 348...
# 1   [0, 57, 118, 129, 137, 203, 214, 237, 244, 256...
# 2   [0, 41, 82, 176, 206, 272, 315, 358, 383, 397,...
# 3   [0, 34, 67, 85, 125, 197, 209, 242, 334, 338, ...
# 4   [0, 15, 93, 117, 227, 321, 326, 446, 563, 575,...
# 5   [0, 33, 77, 141, 374, 394, 591, 622, 741, 800,...
# 6   [0, 16, 21, 45, 58, 75, 83, 117, 133, 150, 169...
# 7   [0, 110, 135, 154, 170, 186, 186, 208, 220, 22...
# 8   [0, 22, 31, 70, 96, 102, 115, 184, 208, 214, 2...
# 9   [0, 12, 49, 118, 146, 269, 309, 319, 371, 398,...
# 10  [0, 48, 61, 111, 156, 212, 226, 246, 251, 326,...
# 11  [0, 44, 58, 80, 92, 99, 128, 152, 161, 297, 37...
# 12  [0, 159, 272, 310, 428, 495, 628, 767, 872, 93...
# 13  [0, 67, 137, 289, 323, 395, 461, 519, 542, 557...
# 14  [0, 9, 14, 27, 63, 203, 252, 301, 328, 384, 50...
# 15  [0, 88, 198, 274, 284, 377, 461, 505, 535, 583...
# 16  [0, 82, 165, 177, 188, 201, 224, 244, 255, 302...
# 17  [0, 24, 46, 100, 125, 162, 194, 292, 346, 442,...
# 18  [0, 38, 99, 175, 288, 423, 483, 502, 569, 619,...
# 19  [0, 34, 58, 138, 181, 187, 249, 291, 321, 344,...
# 20  [0, 72, 89, 106, 122, 135, 190, 213, 276, 285,...
# 21  [0, 39, 63, 111, 130, 249, 335, 446, 496, 525,...
# 22  [0, 7, 22, 54, 106, 185, 218, 248, 274, 283, 3...
# 23  [0, 19, 77, 95, 129, 188, 258, 267, 385, 397, ...
# 24  [0, 32, 52, 96, 106, 115, 130, 162, 176, 197, ...
# 25  [0, 26, 78, 141, 149, 264, 275, 311, 319, 368,...
# 26  [0, 54, 122, 150, 176, 196, 279, 371, 430, 456...
# 27  [0, 36, 131, 159, 196, 237, 271, 311, 333, 353...
# 28  [0, 20, 113, 213, 256, 286, 320, 421, 475, 514...
# 29  [0, 89, 111, 234, 318, 336, 370, 399, 550, 687...
# 30  [0, 45, 106, 129, 176, 185, 195, 272, 328, 368...
# 31  [0, 51, 71, 103, 123, 146, 185, 207, 229, 234,...
#
#                                           end_indices
# 0   [37, 106, 128, 157, 223, 247, 260, 270, 347, 3...
# 1   [56, 117, 128, 136, 202, 213, 236, 243, 255, 2...
# 2   [40, 81, 175, 205, 271, 314, 357, 382, 396, 41...
# 3   [33, 66, 84, 124, 196, 208, 241, 333, 337, 343...
# 4   [14, 92, 116, 226, 320, 325, 445, 562, 574, 67...
# 5   [32, 76, 140, 373, 393, 590, 621, 740, 799, 90...
# 6   [15, 20, 44, 57, 74, 82, 116, 132, 149, 168, 1...
# 7   [109, 134, 153, 169, 185, 196, 196, 219, 225, ...
# 8   [21, 30, 69, 95, 101, 114, 183, 207, 213, 250,...
# 9   [11, 48, 117, 145, 268, 308, 318, 370, 397, 43...
# 10  [47, 60, 110, 155, 211, 225, 245, 250, 325, 34...
# 11  [43, 57, 79, 91, 98, 127, 151, 160, 296, 377, ...
# 12  [158, 271, 309, 427, 494, 627, 766, 871, 935, ...
# 13  [66, 136, 288, 322, 394, 460, 518, 541, 556, 6...
# 14  [8, 13, 26, 62, 202, 251, 300, 327, 383, 501, ...
# 15  [87, 197, 273, 283, 376, 460, 504, 534, 582, 6...
# 16  [81, 164, 176, 187, 200, 223, 243, 254, 301, 3...
# 17  [23, 45, 99, 124, 161, 193, 291, 345, 441, 472...
# 18  [37, 98, 174, 287, 422, 482, 501, 568, 618, 64...
# 19  [33, 57, 137, 180, 186, 248, 290, 320, 343, 39...
# 20  [71, 88, 105, 121, 134, 189, 212, 275, 284, 29...
# 21  [38, 62, 110, 129, 248, 334, 445, 495, 524, 60...
# 22  [6, 21, 53, 105, 184, 217, 247, 273, 282, 313,...
# 23  [18, 76, 94, 128, 187, 257, 266, 384, 396, 402...
# 24  [31, 51, 95, 105, 114, 129, 161, 175, 196, 216...
# 25  [25, 77, 140, 148, 263, 274, 310, 318, 367, 37...
# 26  [53, 121, 149, 175, 195, 278, 370, 429, 455, 4...
# 27  [35, 130, 158, 195, 236, 270, 310, 332, 352, 3...
# 28  [19, 112, 212, 255, 285, 319, 420, 474, 513, 5...
# 29  [88, 110, 233, 317, 335, 369, 398, 549, 686, 8...
# 30  [44, 105, 128, 175, 184, 194, 271, 327, 367, 4...
# 31  [50, 70, 102, 122, 145, 184, 206, 228, 233, 25...
