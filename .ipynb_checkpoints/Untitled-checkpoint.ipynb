# %%
import pandas as pd

# %%
data = pd.read_excel("data_files/QC copy - 1514 - 15 DC contra Vampiros 11.xlsx")

# %%
data
# Out:
#                                 Source text in English  Number of words  \
# 0                                          SMALLVILLE.                1
# 1                                          STILL WARM.                0
# 2                 WHOEVER WAS HERE, THEY LEFT QUICKLY.                6
# 3    SO THESE ARE THE HUMANS WHO HAVE BEEN PICKING ...               13
# 4                          NO. THIS IS ONLY ONE HUMAN.                6
# ..                                                 ...              ...
# 161                      NO. HE'S NOT. HE'S A VAMPIRE.                6
# 162  WHOA. WHOSE BIG BRAIN DID THEY PUT IN THAT HEA...               13
# 163              SPARE PARTS IS RIGHT. I AM A VAMPIRE.                8
# 164  AND I'M YOUR LAST, BEST, AND ONLY SHOT AT STOP...               11
# 165                                   TO BE CONTINUED!                3
#
#      Signs with spaces  Signs without spaces  \
# 0                   11                    11
# ...

# %%
data.iloc[1]['Annotations']
# Out:
# '2024-08-03 - aselermekova20\nFeeling:AN0-DI0-FE2-SA0-SU3-JO0\n\n\n2024-08-03 - aselermekova20\nSpokenBy:ID-1'

# %%
df = pd.read_csv("data_files/QC copy - 1661 - 39 Dragon Age vol. 3 Engano - Deception 2.csv", sep="\t")

# %%
df
# Out:
#                                 Source text in English  Number of words  \
# 0                                             DENERIM.                1
# 1                                     SEVEN YEARS AGO.                3
# 2                  EXCUSE ME. I'M LOOKING FOR A WOMAN.                7
# 3    HER NAME'S ELENA. WE WERE HERE AT YOUR MARKET ...               19
# 4                          NO, MILORD. MANY APOLOGIES.                4
# ..                                                 ...              ...
# 219                                           FLORIAN?                1
# 220                                           FLORIAN!                1
# 221       YOU WERE RIGHT, BIG BROTHER… YOU WERE RIGHT.                8
# 222                      THEY ARE DANGEROUS. AND EVIL.                5
# 223                          AND I WILL MAKE THEM PAY.                6
#
#      Signs with spaces  Signs without spaces  \
# 0                    8                     8
# ...

# %%
df.iloc[3]['Annotations'].split("\n")
# Out:
# ['2024-08-23 - aselermekova20',
#  'Feeling:AN0-DI0-FE2-SA2-SU0-JO0',
#  '',
#  '2024-08-25 - aselermekova20',
#  'SpokenBy:AARON',
#  '']

# %%
df.iloc[4]['Annotations'].split("\n")[1].split(":")[1]
# Out:
# 'AN0-DI0-FE0-SA4-SU5-JO0'
